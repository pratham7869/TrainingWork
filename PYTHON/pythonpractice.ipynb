# %%
a= "python language """
print (a)
print (type(a))
# Out:
# python language
# <class 'str'>

# %%
x= 10
y= "pratham"
z= 10.2
print (x)
print (y)
print (z)
# Out:
# 10
# pratham
# 10.2

# %% [markdown]
# we can get the data type of a variable with

# %%
x = 2
print (type(x))
y= "roy"
print (type(y))
z= 2.3
print (type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
fname , lname = "pratham", "joya"
print ("my name is ", fname , lname)
# my name is pratham joya
# Out:
# my name is  pratham joya

# %%
a,b,c = 2,"john",5.4
print (a,b,c)
print ("a=",a,"b=",b,"c=",c)
# Out:
# 2 john 5.4
# a= 2 b= john c= 5.4

# %%
a,b,c=10,20,2
print (type(a))
print ("a=",a,"b=",b,"c=",c)
print (type(a))
# Out:
# <class 'int'>
# a= 10 b= 20 c= 2
# <class 'int'>

# %%
a,b,c,d = 10,20,30,"john"

print (type(a))
print (type(b))
print (type(c))
print (type(d))

# %%
num = input ("enter any number :")
print ("the number is ", num , "and class is ", type (num))
# Out:
# enter any number :6.8
# the number is  6.8 and class is  <class 'str'>

# %%
num = int (input("enter any number :"))
print ("the number is ", num , "and class is ", type (num))
# Out:
# enter any number :9
# the number is  9 and class is  <class 'int'>

# %% [markdown]
# if i am giving other inputs from int it will give error .

# %%
num = float (input("enter any number :"))
print ("the number is ", num , "and class is ", type (num))
# Out:
# enter any number :8
# the number is  8.0 and class is  <class 'float'>

# %%
name = input ("enter your name ")
print ("name is ", name )
a = int (input ("enter the value of a "))
b = int (input ("enter the value of b "))
print ("sum is ",a+b)
# Out:
# enter your name 4
# name is  4
# enter the value of a 4
# enter the value of b 5
# sum is  9

# %% [markdown]
# seperator :-

# %%
v1,v2,v3,v4= 100,200,300,400
print (v1,v2,v3,v4,sep="i")
print (v1,v2,v3,v4)
print (v1,v2,v3,v4,sep=" ,")
print (v1,v2,v3,v4)
# Out:
# 100i200i300i400
# 100 200 300 400
# 100 ,200 ,300 ,400
# 100 200 300 400

# %% [markdown]
# keyword

# %%
import keyword

# %%
# if statement 
if 14 > 7:

    print("14 is greater than 7")

print("ended")
# Out:
# 14 is greater than 7
# ended

# %%
age = input("enter your age :")
age = int(age)
if age >=15:
  print("your age is above 15")
# Out:
# enter your age :50
# your age is above 15

# %%
x=7
if (x==7):
 {
    print("yes")
 }
 else:
      {
       print("no")
      }
# Out:
#   File "<ipython-input-22-836626749cf6>", line 6
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
age = input("enter your age :")
age = int(age)
if age >=15:
  {
  print("your age is above 15")
  }
  else:
    {
        print("your age is below 15")
    }
# Out:
#   File "<ipython-input-15-66519e91d46e>", line 7
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
 num = int(input("enter any number "))
if num > 1:
  print("positive number")
  elif num == 1:
    print("one")
    elif num < 1:
    print("negative number or zero")
    else:
      print("ended")
# Out:
#   File "<ipython-input-19-ed897f6621dc>", line 4
#     elif num == 1:
#     ^
# SyntaxError: invalid syntax

# %%
 age = int(input("enter your age"))
 if 0<age<=3:
   print("ticket price : free")
elif 3<age<=10:
   print("ticket price : 150")
elif 10<age<=30:
   print("ticket price : 250")
else:
   print("ticket price : 500")
# Out:
# enter your age5
# ticket price : 150

# %%
# nested if statement example 
num = 40
if num> 10: 
  if num <= 20:
    print("between 10 and 20")
else:
      print("number not found")

# %%
num1 = int(input('enter first number '))
num2 = int(input('enter second number '))
if num1 >= num2:
  if num1 == num2:
    print(f"{num1} and {num2},'are equal'")
elif:
      print(f"{num1} is greater than {num2}")
else:
      print(f"{num1} is smaller than {num2}")
# Out:
#   File "<ipython-input-45-555e6d8c0402>", line 6
#     elif:
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# in - keyword

# %%
name = "python"
if 'y' in name:
   print("y is present in name")
else:
     ("y is not present in name")
# Out:
# y is present in name

# %% [markdown]
# iterative statements
# 1. for loop
# 2. while loop

# %%
n = "python"
for x in n:
  {
      #body of loop
      print(x)
  }

print ( "end" )
# Out:
# p
# y
# t
# h
# o
# n
# end

# %%
name = "john"
for i in name:
  {
      #body of loop
      print(i),
      print("done")
  }
  print("end")
  print("done")
# Out:
# j
# done
# end
# done
# o
# done
# end
# done
# h
# done
# end
# done
# n
# done
# end
# done

# %%
name = "python"
for x in name:
  {
      #body of loop
      print(x)
  }
# Out:
# p
# y
# t
# h
# o
# n

# %%
name = "hello"
for x in name:
  print(x)
else:
       print("no items left.")

       print("end")
# Out:
# h
# e
# l
# l
# o
# no items left.
# end

# %%
name= "python"
a = 1
for x in name:
  if(a==1):
    print(x)
else:
  if(x=="n"):
    print("n is a last char ")
# Out:
# p
# y
# t
# h
# o
# n
# n is a last char

# %%
for i in range(10):
  print(f"hello world: {i}")
# Out:
# hello world: 0
# hello world: 1
# hello world: 2
# hello world: 3
# hello world: 4
# hello world: 5
# hello world: 6
# hello world: 7
# hello world: 8
# hello world: 9

# %%
for i in range(10):
  {
      print(f"hello world:{i}")
  }
# Out:
# hello world:0
# hello world:1
# hello world:2
# hello world:3
# hello world:4
# hello world:5
# hello world:6
# hello world:7
# hello world:8
# hello world:9

# %%
n= int(input("enter the number :"))
total = 0
for i in range(1,n+1):
  total += i
  print(total)
# Out:
# enter the number :100
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 105
# 120
# 136
# 153
# 171
# 190
# 210
# 231
# 253
# 276
# 300
# 325
# 351
# 378
# 406
# 435
# 465
# 496
# 528
# 561
# 595
# 630
# 666
# 703
# 741
# 780
# 820
# 861
# 903
# 946
# 990
# 1035
# 1081
# 1128
# 1176
# 1225
# 1275
# 1326
# 1378
# 1431
# 1485
# 1540
# 1596
# 1653
# 1711
# 1770
# 1830
# 1891
# 1953
# 2016
# 2080
# 2145
# 2211
# 2278
# 2346
# 2415
# 2485
# 2556
# 2628
# 2701
# 2775
# 2850
# 2926
# 3003
# 3081
# 3160
# 3240
# 3321
# 3403
# 3486
# 3570
# 3655
# 3741
# 3828
# 3916
# 4005
# 4095
# 4186
# 4278
# 4371
# 4465
# 4560
# 4656
# 4753
# 4851
# 4950
# 5050

# %%
i=1
while i <=5:
  print(f"hello world : {i}")
  i = i+1
  print("program end")
# Out:
# hello world : 1
# program end
# hello world : 2
# program end
# hello world : 3
# program end
# hello world : 4
# program end
# hello world : 5
# program end

# %%
i=8
if(i<=5):
  print("hello world ")
else:
  print("end")
# Out:
# end

# %%
x=10
sum=0
i=1
while i<= x:
  sum = sum +1
  i=i+1
  print(f"the sum is {sum}")
# Out:
# the sum is 1
# the sum is 2
# the sum is 3
# the sum is 4
# the sum is 5
# the sum is 6
# the sum is 7
# the sum is 8
# the sum is 9
# the sum is 10

# %% [markdown]
# while loop with else

# %%
i=1
while i< 8:
  print(i)
  i+=1
else:
  print("i is no longer less than 8")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# i is no longer less than 8

# %%
for x in "python":
  if x == "y":
    break
    print(x)

    print("the end")

# %%
for x in "python":
  if x == "h":
    continue
    print(x)

    print("the end")

# %%
for i in "python":
  if i == "o":
    pass
    print("this is pass block",i)

    print(i)
# Out:
# this is pass block o
# o

# %%
def my_function():
  print("this is a function")

my_function()
# Out:
# this is a function

# %%
def loop():
  name = "python"
      for i in name:
      print(i)

   name()
# Out:
#   File "<tokenize>", line 6
#     name()
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
def my_function(name):
  return("hello",name)

  result=

# %% [markdown]
# pandasBasics

# %%
# %matplotlib inline 
import numpy as np
import pandas as pd 

df = pd.read_csv("/content/drive/MyDrive/Da folder/PastHires.csv")
#df.head(10)

#df.tail(4)
df.shape
len(df)
df.columns
# Out:
# Index(['Years Experience', 'Employed?', 'Previous employers',
#        'Level of Education', 'Top-tier school', 'Interned', 'Hired'],
#       dtype='object')

# %%
df['Hired']
df[['Hired','Years Experience']][3:5]
# Out:
#   Hired  Years Experience
# 3     Y                 2
# 4     N                20

# %%
df.sort_values(['Years Experience'])
# Out:
#     Years Experience Employed?  Previous employers Level of Education  \
# 1                  0         N                   0                 BS
# 5                  0         N                   0                PhD
# 9                  0         N                   0                 BS
# 12                 0         N                   0                PhD
# 10                 1         N                   1                PhD
# 3                  2         Y                   1                 MS
# 7                  3         N                   1                 BS
# 11                 4         Y                   1                 BS
# 6                  5         Y                   2                 MS
# 2                  7         N                   6                 BS
# 0                 10         Y                   4                 BS
# 8                 15         Y                   5                 BS
# ...

# %%
degree_counts = df['Level of Education'].value_counts()
degree_counts
# Out:
# BS     7
# PhD    4
# MS     2
# Name: Level of Education, dtype: int64

# %%
degree_counts.plot(kind='bar')

# %% [markdown]
# exercise
# try extracting raw 5-10 of our dataframe , preserving only the previous "employers"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
